# %%
import cv2
import os
import numpy as np

# Function to find and process green rectangles
def find_green_rectangle(image_path):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Image not found: {image_path}")

    # Convert the image to HSV color space
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define the range for the green color in HSV
    lower_green = np.array([35, 100, 100])
    upper_green = np.array([85, 255, 255])

    # Create a mask for the green color
    mask = cv2.inRange(hsv_image, lower_green, upper_green)

    # Initialize the output image as black
    output_image = np.zeros_like(mask)

    # Find contours in the mask
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        if w > 10 and h > 10:  # Ensure the rectangle is large enough
            # Fill the detected green region with white in the output image
            output_image[y:y+h, x:x+w] = 255

    return output_image

# Define paths
input_folder = 'data/label/'
output_folder = 'ground image/'

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process each image in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.png') or filename.endswith('.jpg') or filename.endswith('.jpeg'):
        image_path = os.path.join(input_folder, filename)
        try:
            # Process the image to detect green regions and generate the binary output
            result_image = find_green_rectangle(image_path)
            
            # Save the result
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, result_image)
            print(f"Processed and saved: {filename}")
        except ValueError as e:
            print(e)

print("Processing complete. Check the 'ground image' folder for results.")
# Out:
# Processed and saved: 037.jpeg
# Processed and saved: 060.jpeg
# Processed and saved: 021.jpeg
# Processed and saved: 056.jpeg
# Processed and saved: 001.jpeg
# Processed and saved: 017.jpeg
# Processed and saved: 040.jpeg
# Processed and saved: 041.jpeg
# Processed and saved: 016.jpeg
# Processed and saved: 057.jpeg
# Processed and saved: 020.jpeg
# Processed and saved: 061.jpeg
# Processed and saved: 036.jpeg
# Processed and saved: 050.jpeg
# Processed and saved: 007.jpeg
# Processed and saved: 011.jpeg
# Processed and saved: 046.jpeg
# Processed and saved: 031.jpeg
# Processed and saved: 066.jpeg
# Processed and saved: 027.jpeg
# Processed and saved: 026.jpeg
# Processed and saved: 030.jpeg
# Processed and saved: 047.jpeg
# Processed and saved: 010.jpeg
# Processed and saved: 006.jpeg
# Processed and saved: 051.jpeg
# Processed and saved: 029.jpeg
# Processed and saved: 044.jpeg
# Processed and saved: 013.jpeg
# Processed and saved: 005.jpeg
# Processed and saved: 052.jpeg
# Processed and saved: 025.jpeg
# Processed and saved: 064.jpeg
# Processed and saved: 033.jpeg
# Processed and saved: 048.jpeg
# Processed and saved: 009.jpeg
# Processed and saved: 008.jpeg
# Processed and saved: 049.jpeg
# Processed and saved: 032.jpeg
# Processed and saved: 065.jpeg
# Processed and saved: 024.jpeg
# Processed and saved: 053.jpeg
# Processed and saved: 004.jpeg
# Processed and saved: 012.jpeg
# Processed and saved: 045.jpeg
# Processed and saved: 028.jpeg
# Processed and saved: 023.jpeg
# Processed and saved: 062.jpeg
# Processed and saved: 035.jpeg
# Processed and saved: 019.jpeg
# Processed and saved: 058.jpeg
# Processed and saved: 039.jpeg
# Processed and saved: 042.jpeg
# Processed and saved: 015.jpeg
# Processed and saved: 003.jpeg
# Processed and saved: 054.jpeg
# Processed and saved: 055.jpeg
# Processed and saved: 002.jpeg
# Processed and saved: 014.jpeg
# Processed and saved: 043.jpeg
# Processed and saved: 038.jpeg
# Processed and saved: 059.jpeg
# Processed and saved: 018.jpeg
# Processed and saved: 034.jpeg
# Processed and saved: 063.jpeg
# Processed and saved: 022.jpeg
# Processing complete. Check the 'ground image' folder for results.
# libpng warning: iCCP: extra compressed data

# %% [markdown]
# resizing

# %%
import cv2
import os

# Define the desired dimensions
resize_dimensions = (256, 256)

# Define paths
input_folder = 'ground image/'
output_folder = 'resize/resized_images/'

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process each image in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.png') or filename.endswith('.jpg') or filename.endswith('.jpeg'):
        image_path = os.path.join(input_folder, filename)
        
        # Load the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Skipping file: {filename}")
            continue

        # Resize the image
        resized_image = cv2.resize(image, resize_dimensions)
        
        # Save the resized image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, resized_image)
        print(f"Resized and saved: {filename}")

print("Resizing complete. Check the 'resized images' folder for results.")
# Out:
# Resized and saved: 037.jpeg
# Resized and saved: 060.jpeg
# Resized and saved: 021.jpeg
# Resized and saved: 056.jpeg
# Resized and saved: 001.jpeg
# Resized and saved: 017.jpeg
# Resized and saved: 040.jpeg
# Resized and saved: 041.jpeg
# Resized and saved: 016.jpeg
# Resized and saved: 057.jpeg
# Resized and saved: 020.jpeg
# Resized and saved: 061.jpeg
# Resized and saved: 036.jpeg
# Resized and saved: 050.jpeg
# Resized and saved: 007.jpeg
# Resized and saved: 011.jpeg
# Resized and saved: 046.jpeg
# Resized and saved: 031.jpeg
# Resized and saved: 066.jpeg
# Resized and saved: 027.jpeg
# Resized and saved: 026.jpeg
# Resized and saved: 030.jpeg
# Resized and saved: 047.jpeg
# Resized and saved: 010.jpeg
# Resized and saved: 006.jpeg
# Resized and saved: 051.jpeg
# Resized and saved: 029.jpeg
# Resized and saved: 044.jpeg
# Resized and saved: 013.jpeg
# Resized and saved: 005.jpeg
# Resized and saved: 052.jpeg
# Resized and saved: 025.jpeg
# Resized and saved: 064.jpeg
# Resized and saved: 033.jpeg
# Resized and saved: 048.jpeg
# Resized and saved: 009.jpeg
# Resized and saved: 008.jpeg
# Resized and saved: 049.jpeg
# Resized and saved: 032.jpeg
# Resized and saved: 065.jpeg
# Resized and saved: 024.jpeg
# Resized and saved: 053.jpeg
# Resized and saved: 004.jpeg
# Resized and saved: 012.jpeg
# Resized and saved: 045.jpeg
# Resized and saved: 028.jpeg
# Resized and saved: 023.jpeg
# Resized and saved: 062.jpeg
# Resized and saved: 035.jpeg
# Resized and saved: 019.jpeg
# Resized and saved: 058.jpeg
# Resized and saved: 039.jpeg
# Resized and saved: 042.jpeg
# Resized and saved: 015.jpeg
# Resized and saved: 003.jpeg
# Resized and saved: 054.jpeg
# Resized and saved: 055.jpeg
# Resized and saved: 002.jpeg
# Resized and saved: 014.jpeg
# Resized and saved: 043.jpeg
# Resized and saved: 038.jpeg
# Resized and saved: 059.jpeg
# Resized and saved: 018.jpeg
# Resized and saved: 034.jpeg
# Resized and saved: 063.jpeg
# Resized and saved: 022.jpeg
# Resizing complete. Check the 'resized images' folder for results.

# %%
import cv2
import os

# Define the desired dimensions
resize_dimensions = (256, 256)

# Define paths
input_folder = 'data/not_label/'
output_folder = 'resize/resized_RAWimages/'

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process each image in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.png') or filename.endswith('.jpg') or filename.endswith('.jpeg'):
        image_path = os.path.join(input_folder, filename)
        
        # Load the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Skipping file: {filename}")
            continue

        # Resize the image
        resized_image = cv2.resize(image, resize_dimensions)
        
        # Save the resized image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, resized_image)
        print(f"Resized and saved: {filename}")

print("Resizing complete. Check the 'resized images' folder for results.")
# Out:
# Resized and saved: 037.jpeg
# Resized and saved: 060.jpeg
# Resized and saved: 021.jpeg
# Resized and saved: 056.jpeg
# Resized and saved: 001.jpeg
# Resized and saved: 017.jpeg
# Resized and saved: 040.jpeg
# Resized and saved: 041.jpeg
# Resized and saved: 016.jpeg
# Resized and saved: 057.jpeg
# Resized and saved: 020.jpeg
# Resized and saved: 061.jpeg
# Resized and saved: 036.jpeg
# Resized and saved: 050.jpeg
# Resized and saved: 007.jpeg
# Resized and saved: 011.jpeg
# Resized and saved: 046.jpeg
# Resized and saved: 031.jpeg
# Resized and saved: 066.jpeg
# Resized and saved: 027.jpeg
# Resized and saved: 026.jpeg
# Resized and saved: 030.jpeg
# Resized and saved: 047.jpeg
# Resized and saved: 010.jpeg
# Resized and saved: 006.jpeg
# Resized and saved: 051.jpeg
# Resized and saved: 029.jpeg
# Resized and saved: 044.jpeg
# Resized and saved: 013.jpeg
# Resized and saved: 005.jpeg
# Resized and saved: 052.jpeg
# Resized and saved: 025.jpeg
# Resized and saved: 064.jpeg
# Resized and saved: 033.jpeg
# Resized and saved: 048.jpeg
# Resized and saved: 009.jpeg
# Resized and saved: 008.jpeg
# Resized and saved: 049.jpeg
# Resized and saved: 032.jpeg
# Resized and saved: 065.jpeg
# Resized and saved: 024.jpeg
# Resized and saved: 053.jpeg
# Resized and saved: 004.jpeg
# Resized and saved: 012.jpeg
# Resized and saved: 045.jpeg
# Resized and saved: 028.jpeg
# Resized and saved: 023.jpeg
# Resized and saved: 062.jpeg
# Resized and saved: 035.jpeg
# Resized and saved: 019.jpeg
# Resized and saved: 058.jpeg
# Resized and saved: 039.jpeg
# Resized and saved: 042.jpeg
# Resized and saved: 015.jpeg
# Resized and saved: 003.jpeg
# Resized and saved: 054.jpeg
# Resized and saved: 055.jpeg
# Resized and saved: 002.jpeg
# Resized and saved: 014.jpeg
# Resized and saved: 043.jpeg
# Resized and saved: 038.jpeg
# Resized and saved: 059.jpeg
# Resized and saved: 018.jpeg
# Resized and saved: 034.jpeg
# Resized and saved: 063.jpeg
# Resized and saved: 022.jpeg
# Resizing complete. Check the 'resized images' folder for results.
# libpng warning: iCCP: extra compressed data

# %% [markdown]
# Normalization

# %%
import cv2
import os
import numpy as np

def normalize_image(image_path):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Image not found: {image_path}")

    # Convert the image to a float32 array and normalize to [0, 1]
    normalized_image = image.astype('float32') / 255.0

    return normalized_image

# Define paths
input_folder = 'resize/resized_RAWimages/'  # Replace with your input folder path
output_folder = 'normalization/normalizated_RAWimg'  # Replace with your output folder path

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process each image in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.png') or filename.endswith('.jpg') or filename.endswith('.jpeg'):
        image_path = os.path.join(input_folder, filename)
        
        try:
            # Normalize the image
            normalized_image = normalize_image(image_path)

            # Convert back to 8-bit format for saving
            output_image = (normalized_image * 255).astype('uint8')

            # Save the normalized image
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, output_image)
            print(f"Normalized and saved: {filename}")
        
        except ValueError as e:
            print(e)

print("Normalization complete. Check the output folder for results.")
# Out:
# Normalized and saved: 037.jpeg
# Normalized and saved: 060.jpeg
# Normalized and saved: 021.jpeg
# Normalized and saved: 056.jpeg
# Normalized and saved: 001.jpeg
# Normalized and saved: 017.jpeg
# Normalized and saved: 040.jpeg
# Normalized and saved: 041.jpeg
# Normalized and saved: 016.jpeg
# Normalized and saved: 057.jpeg
# Normalized and saved: 020.jpeg
# Normalized and saved: 061.jpeg
# Normalized and saved: 036.jpeg
# Normalized and saved: 050.jpeg
# Normalized and saved: 007.jpeg
# Normalized and saved: 011.jpeg
# Normalized and saved: 046.jpeg
# Normalized and saved: 031.jpeg
# Normalized and saved: 066.jpeg
# Normalized and saved: 027.jpeg
# Normalized and saved: 026.jpeg
# Normalized and saved: 030.jpeg
# Normalized and saved: 047.jpeg
# Normalized and saved: 010.jpeg
# Normalized and saved: 006.jpeg
# Normalized and saved: 051.jpeg
# Normalized and saved: 029.jpeg
# Normalized and saved: 044.jpeg
# Normalized and saved: 013.jpeg
# Normalized and saved: 005.jpeg
# Normalized and saved: 052.jpeg
# Normalized and saved: 025.jpeg
# Normalized and saved: 064.jpeg
# Normalized and saved: 033.jpeg
# Normalized and saved: 048.jpeg
# Normalized and saved: 009.jpeg
# Normalized and saved: 008.jpeg
# Normalized and saved: 049.jpeg
# Normalized and saved: 032.jpeg
# Normalized and saved: 065.jpeg
# Normalized and saved: 024.jpeg
# Normalized and saved: 053.jpeg
# Normalized and saved: 004.jpeg
# Normalized and saved: 012.jpeg
# Normalized and saved: 045.jpeg
# Normalized and saved: 028.jpeg
# Normalized and saved: 023.jpeg
# Normalized and saved: 062.jpeg
# Normalized and saved: 035.jpeg
# Normalized and saved: 019.jpeg
# Normalized and saved: 058.jpeg
# Normalized and saved: 039.jpeg
# Normalized and saved: 042.jpeg
# Normalized and saved: 015.jpeg
# Normalized and saved: 003.jpeg
# Normalized and saved: 054.jpeg
# Normalized and saved: 055.jpeg
# Normalized and saved: 002.jpeg
# Normalized and saved: 014.jpeg
# Normalized and saved: 043.jpeg
# Normalized and saved: 038.jpeg
# Normalized and saved: 059.jpeg
# Normalized and saved: 018.jpeg
# Normalized and saved: 034.jpeg
# Normalized and saved: 063.jpeg
# Normalized and saved: 022.jpeg
# Normalization complete. Check the output folder for results.

# %% [markdown]
# split

# %%
import os
import shutil
import numpy as np
from sklearn.model_selection import train_test_split

# Define paths
raw_image_folder = 'normalization/normalizated_RAWimg/'  # Replace with the path to your raw images
ground_image_folder = 'ground image/'  # Replace with the path to your ground truth images
output_folder = 'split/'  # The base folder where the splits will be saved

# Create subdirectories for train, validation, and test splits
for split_type in ['train', 'validation', 'test']:
    os.makedirs(os.path.join(output_folder, split_type, 'raw'), exist_ok=True)
    os.makedirs(os.path.join(output_folder, split_type, 'ground'), exist_ok=True)

# List all raw images
raw_images = [f for f in os.listdir(raw_image_folder) if f.endswith('.png') or f.endswith('.jpg') or f.endswith('.jpeg')]

# Split the dataset into training, validation, and test sets (e.g., 70%, 15%, 15%)
train_images, test_images = train_test_split(raw_images, test_size=0.3, random_state=42)
val_images, test_images = train_test_split(test_images, test_size=0.5, random_state=42)

def move_files(image_list, split_type):
    for filename in image_list:
        raw_image_path = os.path.join(raw_image_folder, filename)
        ground_image_path = os.path.join(ground_image_folder, filename)
        
        if os.path.exists(raw_image_path) and os.path.exists(ground_image_path):
            # Move raw images
            shutil.copy(raw_image_path, os.path.join(output_folder, split_type, 'raw', filename))
            # Move ground truth images
            shutil.copy(ground_image_path, os.path.join(output_folder, split_type, 'ground', filename))
        else:
            print(f"Corresponding ground truth for {filename} not found.")

# Move files to respective folders
move_files(train_images, 'train')
move_files(val_images, 'validation')
move_files(test_images, 'test')

print("Dataset split and copying complete. Check the 'split/' folder for results.")
# Out:
# Dataset split and copying complete. Check the 'split/' folder for results.

# %% [markdown]
# model

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras import layers, models

def unet_resnet152(input_shape):
    # Load ResNet152V2 model as the encoder
    resnet = ResNet152V2(weights='imagenet', include_top=False, input_shape=input_shape)
    
    # Encoder outputs
    encoder_outputs = {
        'block1': resnet.get_layer("conv1_conv").output,
        'block2': resnet.get_layer("conv2_block3_out").output,
        'block3': resnet.get_layer("conv3_block4_out").output,
        'block4': resnet.get_layer("conv4_block6_out").output
    }
    
    # Decoder
    x = layers.Conv2DTranspose(512, (3, 3), strides=(2, 2), padding='same')(encoder_outputs['block4'])
    x = layers.concatenate([x, encoder_outputs['block3']], axis=-1)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)

    x = layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same')(x)
    # Upsample block2 to match the spatial size of x
    block2_upsampled = layers.UpSampling2D(size=(2, 2))(encoder_outputs['block2'])
    x = layers.concatenate([x, block2_upsampled], axis=-1)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)

    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(x)
    # Adjust the dimensions before concatenation
    x = layers.Cropping2D(cropping=((0, 1), (0, 1)))(x)  # Crop x to match encoder_outputs['block1']
    # Crop block1 to match the spatial size of x
    block1_cropped = layers.Cropping2D(cropping=((1, 0), (1, 0)))(encoder_outputs['block1'])
    x = layers.concatenate([x, block1_cropped], axis=-1)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)

    # Output layer
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(x)

    # Define and compile the model
    model = models.Model(inputs=resnet.input, outputs=outputs)
    return model

# Example usage
input_shape = (256, 256, 3)  # Define your input shape
model = unet_resnet152(input_shape)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_17      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 262, 262,  │          0 │ input_layer_17[0… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 128, 128,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 130, 130,  │          0 │ conv1_conv[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 64, 64,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 64, 64,    │        256 │ pool1_pool[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 64, 64,    │          0 │ conv2_block1_pre… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 64, 64,    │      4,096 │ conv2_block1_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 64, 64,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 64, 64,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_pad  │ (None, 66, 66,    │          0 │ conv2_block1_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 64, 64,    │     36,864 │ conv2_block1_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 64, 64,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 64, 64,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 64, 64,    │     16,640 │ conv2_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 64, 64,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 64, 64,    │          0 │ conv2_block1_0_c… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 64, 64,    │      1,024 │ conv2_block1_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 64, 64,    │          0 │ conv2_block2_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 64, 64,    │     16,384 │ conv2_block2_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 64, 64,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 64, 64,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_pad  │ (None, 66, 66,    │          0 │ conv2_block2_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 64, 64,    │     36,864 │ conv2_block2_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 64, 64,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 64, 64,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 64, 64,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 64, 64,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 64, 64,    │      1,024 │ conv2_block2_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 64, 64,    │          0 │ conv2_block3_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 64, 64,    │     16,384 │ conv2_block3_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 64, 64,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 64, 64,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_pad  │ (None, 66, 66,    │          0 │ conv2_block3_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 32, 32,    │     36,864 │ conv2_block3_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 32, 32,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 32, 32,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_51    │ (None, 32, 32,    │          0 │ conv2_block2_out… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 32, 32,    │          0 │ max_pooling2d_51… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 32, 32,    │      1,024 │ conv2_block3_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 32, 32,    │          0 │ conv3_block1_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 32, 32,    │     32,768 │ conv3_block1_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 32, 32,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 32, 32,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_pad  │ (None, 34, 34,    │          0 │ conv3_block1_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 32, 32,    │    147,456 │ conv3_block1_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 32, 32,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 32, 32,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 32, 32,    │    131,584 │ conv3_block1_pre… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 32, 32,    │          0 │ conv3_block1_0_c… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 32, 32,    │      2,048 │ conv3_block1_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 32, 32,    │          0 │ conv3_block2_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 32, 32,    │     65,536 │ conv3_block2_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 32, 32,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 32, 32,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_pad  │ (None, 34, 34,    │          0 │ conv3_block2_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 32, 32,    │    147,456 │ conv3_block2_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 32, 32,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 32, 32,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 32, 32,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 32, 32,    │      2,048 │ conv3_block2_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 32, 32,    │          0 │ conv3_block3_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 32, 32,    │     65,536 │ conv3_block3_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 32, 32,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 32, 32,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_pad  │ (None, 34, 34,    │          0 │ conv3_block3_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 32, 32,    │    147,456 │ conv3_block3_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 32, 32,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 32, 32,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 32, 32,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 32, 32,    │      2,048 │ conv3_block3_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 32, 32,    │          0 │ conv3_block4_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 32, 32,    │     65,536 │ conv3_block4_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 32, 32,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 32, 32,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_pad  │ (None, 34, 34,    │          0 │ conv3_block4_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 32, 32,    │    147,456 │ conv3_block4_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 32, 32,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 32, 32,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 32, 32,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_preac… │ (None, 32, 32,    │      2,048 │ conv3_block4_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_preac… │ (None, 32, 32,    │          0 │ conv3_block5_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_conv │ (None, 32, 32,    │     65,536 │ conv3_block5_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_bn   │ (None, 32, 32,    │        512 │ conv3_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_relu │ (None, 32, 32,    │          0 │ conv3_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_pad  │ (None, 34, 34,    │          0 │ conv3_block5_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_conv │ (None, 32, 32,    │    147,456 │ conv3_block5_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_bn   │ (None, 32, 32,    │        512 │ conv3_block5_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_relu │ (None, 32, 32,    │          0 │ conv3_block5_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block5_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_out    │ (None, 32, 32,    │          0 │ conv3_block4_out… │
# │ (Add)               │ 512)              │            │ conv3_block5_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_preac… │ (None, 32, 32,    │      2,048 │ conv3_block5_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_preac… │ (None, 32, 32,    │          0 │ conv3_block6_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_conv │ (None, 32, 32,    │     65,536 │ conv3_block6_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_bn   │ (None, 32, 32,    │        512 │ conv3_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_relu │ (None, 32, 32,    │          0 │ conv3_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_pad  │ (None, 34, 34,    │          0 │ conv3_block6_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_conv │ (None, 32, 32,    │    147,456 │ conv3_block6_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_bn   │ (None, 32, 32,    │        512 │ conv3_block6_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_relu │ (None, 32, 32,    │          0 │ conv3_block6_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block6_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_out    │ (None, 32, 32,    │          0 │ conv3_block5_out… │
# │ (Add)               │ 512)              │            │ conv3_block6_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_preac… │ (None, 32, 32,    │      2,048 │ conv3_block6_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_preac… │ (None, 32, 32,    │          0 │ conv3_block7_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_conv │ (None, 32, 32,    │     65,536 │ conv3_block7_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_bn   │ (None, 32, 32,    │        512 │ conv3_block7_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_relu │ (None, 32, 32,    │          0 │ conv3_block7_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_pad  │ (None, 34, 34,    │          0 │ conv3_block7_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_conv │ (None, 32, 32,    │    147,456 │ conv3_block7_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_bn   │ (None, 32, 32,    │        512 │ conv3_block7_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_relu │ (None, 32, 32,    │          0 │ conv3_block7_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_3_conv │ (None, 32, 32,    │     66,048 │ conv3_block7_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_out    │ (None, 32, 32,    │          0 │ conv3_block6_out… │
# │ (Add)               │ 512)              │            │ conv3_block7_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_preac… │ (None, 32, 32,    │      2,048 │ conv3_block7_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_preac… │ (None, 32, 32,    │          0 │ conv3_block8_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_conv │ (None, 32, 32,    │     65,536 │ conv3_block8_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_bn   │ (None, 32, 32,    │        512 │ conv3_block8_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_relu │ (None, 32, 32,    │          0 │ conv3_block8_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_pad  │ (None, 34, 34,    │          0 │ conv3_block8_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_conv │ (None, 16, 16,    │    147,456 │ conv3_block8_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_bn   │ (None, 16, 16,    │        512 │ conv3_block8_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_relu │ (None, 16, 16,    │          0 │ conv3_block8_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_52    │ (None, 16, 16,    │          0 │ conv3_block7_out… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block8_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_out    │ (None, 16, 16,    │          0 │ max_pooling2d_52… │
# │ (Add)               │ 512)              │            │ conv3_block8_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 16, 16,    │      2,048 │ conv3_block8_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 16, 16,    │          0 │ conv4_block1_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 16, 16,    │    131,072 │ conv4_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 16, 16,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_pad  │ (None, 18, 18,    │          0 │ conv4_block1_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 16, 16,    │    589,824 │ conv4_block1_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 16, 16,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 16, 16,    │    525,312 │ conv4_block1_pre… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 16, 16,    │          0 │ conv4_block1_0_c… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 16, 16,    │      4,096 │ conv4_block1_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 16, 16,    │          0 │ conv4_block2_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 16, 16,    │    262,144 │ conv4_block2_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 16, 16,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_pad  │ (None, 18, 18,    │          0 │ conv4_block2_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 16, 16,    │    589,824 │ conv4_block2_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 16, 16,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 16, 16,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 16, 16,    │      4,096 │ conv4_block2_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 16, 16,    │          0 │ conv4_block3_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 16, 16,    │    262,144 │ conv4_block3_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 16, 16,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_pad  │ (None, 18, 18,    │          0 │ conv4_block3_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 16, 16,    │    589,824 │ conv4_block3_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 16, 16,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 16, 16,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 16, 16,    │      4,096 │ conv4_block3_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 16, 16,    │          0 │ conv4_block4_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 16, 16,    │    262,144 │ conv4_block4_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 16, 16,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_pad  │ (None, 18, 18,    │          0 │ conv4_block4_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 16, 16,    │    589,824 │ conv4_block4_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 16, 16,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 16, 16,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 16, 16,    │      4,096 │ conv4_block4_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 16, 16,    │          0 │ conv4_block5_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 16, 16,    │    262,144 │ conv4_block5_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 16, 16,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_pad  │ (None, 18, 18,    │          0 │ conv4_block5_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 16, 16,    │    589,824 │ conv4_block5_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 16, 16,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 16, 16,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 16, 16,    │      4,096 │ conv4_block5_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 16, 16,    │          0 │ conv4_block6_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 16, 16,    │    262,144 │ conv4_block6_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 16, 16,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 16, 16,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_pad  │ (None, 18, 18,    │          0 │ conv4_block6_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 16, 16,    │    589,824 │ conv4_block6_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 16, 16,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 16, 16,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 16, 16,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 16, 16,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_26 │ (None, 32, 32,    │  4,719,104 │ conv4_block6_out… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv3_block4_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 32, 32,    │  4,719,104 │ concatenate_26[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_40[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_27 │ (None, 64, 64,    │  1,179,904 │ conv2d_41[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ conv2_block3_out… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ up_sampling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_27[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_42[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_28 │ (None, 128, 128,  │    295,040 │ conv2d_43[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cropping2d_3        │ (None, 127, 127,  │          0 │ conv2d_transpose… │
# │ (Cropping2D)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cropping2d_4        │ (None, 127, 127,  │          0 │ conv1_conv[0][0]  │
# │ (Cropping2D)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_28      │ (None, 127, 127,  │          0 │ cropping2d_3[0][… │
# │ (Concatenate)       │ 192)              │            │ cropping2d_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 127, 127,  │    221,312 │ concatenate_28[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 127, 127,  │    147,584 │ conv2d_44[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 127, 127,  │        129 │ conv2d_45[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 25,113,857 (95.80 MB)
#  Trainable params: 25,082,753 (95.68 MB)
#  Non-trainable params: 31,104 (121.50 KB)

# %% [markdown]
# datagenerator

# %%
import tensorflow as tf

def parse_image(image_path, mask_path):
    # Load image and mask
    image = tf.io.read_file(image_path)
    image = tf.image.decode_image(image, channels=3)
    image = tf.image.resize(image, [256, 256])  # Resize if necessary
    image = tf.cast(image, tf.float32) / 255.0  # Normalize
    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_image(mask, channels=1)
    mask = tf.image.resize(mask, [256, 256])  # Resize if necessary
    mask = tf.cast(mask, tf.float32) / 255.0  # Normalize
    
    return image, mask

def create_dataset(image_paths, mask_paths, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    dataset = dataset.map(lambda img, msk: tf.numpy_function(func=parse_image, inp=[img, msk], Tout=(tf.float32, tf.float32)))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

# %%
import os
import shutil
import tensorflow as tf

# Define source and destination directories
source_dirs = {
    'split/train/raw': 'final/train/raw',
    'split/train/ground': 'final/train/ground',
    'split/validation/raw': 'final/validation/raw',
    'split/validation/ground': 'final/validation/ground',
    'split/test/raw': 'final/test/raw',
    'split/test/ground': 'final/test/ground'
}

# Create destination directories if they don't exist
for src_dir, dest_dir in source_dirs.items():
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

# Copy files from source directories to destination directories
for src_dir, dest_dir in source_dirs.items():
    for fname in os.listdir(src_dir):
        src_path = os.path.join(src_dir, fname)
        dest_path = os.path.join(dest_dir, fname)
        shutil.copy(src_path, dest_path)
        print(f"Copied {src_path} to {dest_path}")

# Verify the content of destination directories
def list_files(directory):
    return os.listdir(directory)

print("Train raw files:", list_files('final/train/raw'))
print("Train ground files:", list_files('final/train/ground'))
print("Validation raw files:", list_files('final/validation/raw'))
print("Validation ground files:", list_files('final/validation/ground'))
print("Test raw files:", list_files('final/test/raw'))
print("Test ground files:", list_files('final/test/ground'))

# Define a function to parse images and masks
def parse_image(image_path, mask_path):
    # Load image and mask
    image = tf.io.read_file(image_path)
    image = tf.image.decode_image(image, channels=3)
    image = tf.image.resize(image, [256, 256])  # Resize if necessary
    image = tf.cast(image, tf.float32) / 255.0  # Normalize
    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_image(mask, channels=1)
    mask = tf.image.resize(mask, [256, 256])  # Resize if necessary
    mask = tf.cast(mask, tf.float32) / 255.0  # Normalize
    
    return image, mask

# Define a function to create a dataset
def create_dataset(image_paths, mask_paths, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    dataset = dataset.map(lambda img, msk: tf.numpy_function(func=parse_image, inp=[img, msk], Tout=(tf.float32, tf.float32)))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

# List and sort file paths
train_img_paths = sorted(['final/train/raw/' + fname for fname in os.listdir('final/train/raw')])
train_mask_paths = sorted(['final/train/ground/' + fname for fname in os.listdir('final/train/ground/')])

val_img_paths = sorted(['final/validation/raw/' + fname for fname in os.listdir('final/validation/raw/')])
val_mask_paths = sorted(['final/validation/ground/' + fname for fname in os.listdir('final/validation/ground/')])

test_img_paths = sorted(['final/test/raw/' + fname for fname in os.listdir('final/test/raw/')])
test_mask_paths = sorted(['final/test/ground/' + fname for fname in os.listdir('final/test/ground/')])

# Define batch size
batch_size = 32

# Create datasets
train_dataset = create_dataset(train_img_paths, train_mask_paths, batch_size)
val_dataset = create_dataset(val_img_paths, val_mask_paths, batch_size)
test_dataset = create_dataset(test_img_paths, test_mask_paths, batch_size)

# Print dataset information including shapes of the tensors
def print_shapes(dataset, num_samples=1):
    for images, masks in dataset.take(num_samples):
        print("Image batch shape:", images.shape)
        print("Mask batch shape:", masks.shape)

print("Training dataset:")
print_shapes(train_dataset)

print("Validation dataset:")
print_shapes(val_dataset)

print("Test dataset:")
print_shapes(test_dataset)
# Out:
# Copied split/train/raw/060.jpeg to final/train/raw/060.jpeg
# Copied split/train/raw/021.jpeg to final/train/raw/021.jpeg
# Copied split/train/raw/001.jpeg to final/train/raw/001.jpeg
# Copied split/train/raw/040.jpeg to final/train/raw/040.jpeg
# Copied split/train/raw/041.jpeg to final/train/raw/041.jpeg
# Copied split/train/raw/020.jpeg to final/train/raw/020.jpeg
# Copied split/train/raw/061.jpeg to final/train/raw/061.jpeg
# Copied split/train/raw/007.jpeg to final/train/raw/007.jpeg
# Copied split/train/raw/011.jpeg to final/train/raw/011.jpeg
# Copied split/train/raw/066.jpeg to final/train/raw/066.jpeg
# Copied split/train/raw/027.jpeg to final/train/raw/027.jpeg
# Copied split/train/raw/026.jpeg to final/train/raw/026.jpeg
# Copied split/train/raw/030.jpeg to final/train/raw/030.jpeg
# Copied split/train/raw/047.jpeg to final/train/raw/047.jpeg
# Copied split/train/raw/010.jpeg to final/train/raw/010.jpeg
# Copied split/train/raw/006.jpeg to final/train/raw/006.jpeg
# Copied split/train/raw/029.jpeg to final/train/raw/029.jpeg
# Copied split/train/raw/044.jpeg to final/train/raw/044.jpeg
# Copied split/train/raw/013.jpeg to final/train/raw/013.jpeg
# Copied split/train/raw/005.jpeg to final/train/raw/005.jpeg
# Copied split/train/raw/025.jpeg to final/train/raw/025.jpeg
# Copied split/train/raw/064.jpeg to final/train/raw/064.jpeg
# Copied split/train/raw/009.jpeg to final/train/raw/009.jpeg
# Copied split/train/raw/008.jpeg to final/train/raw/008.jpeg
# Copied split/train/raw/049.jpeg to final/train/raw/049.jpeg
# Copied split/train/raw/032.jpeg to final/train/raw/032.jpeg
# Copied split/train/raw/065.jpeg to final/train/raw/065.jpeg
# Copied split/train/raw/004.jpeg to final/train/raw/004.jpeg
# Copied split/train/raw/012.jpeg to final/train/raw/012.jpeg
# Copied split/train/raw/045.jpeg to final/train/raw/045.jpeg
# Copied split/train/raw/023.jpeg to final/train/raw/023.jpeg
# Copied split/train/raw/062.jpeg to final/train/raw/062.jpeg
# Copied split/train/raw/035.jpeg to final/train/raw/035.jpeg
# Copied split/train/raw/019.jpeg to final/train/raw/019.jpeg
# Copied split/train/raw/058.jpeg to final/train/raw/058.jpeg
# Copied split/train/raw/039.jpeg to final/train/raw/039.jpeg
# Copied split/train/raw/042.jpeg to final/train/raw/042.jpeg
# Copied split/train/raw/015.jpeg to final/train/raw/015.jpeg
# Copied split/train/raw/054.jpeg to final/train/raw/054.jpeg
# Copied split/train/raw/055.jpeg to final/train/raw/055.jpeg
# Copied split/train/raw/002.jpeg to final/train/raw/002.jpeg
# Copied split/train/raw/014.jpeg to final/train/raw/014.jpeg
# Copied split/train/raw/043.jpeg to final/train/raw/043.jpeg
# Copied split/train/raw/038.jpeg to final/train/raw/038.jpeg
# Copied split/train/raw/059.jpeg to final/train/raw/059.jpeg
# Copied split/train/raw/063.jpeg to final/train/raw/063.jpeg
# Copied split/train/ground/060.jpeg to final/train/ground/060.jpeg
# Copied split/train/ground/021.jpeg to final/train/ground/021.jpeg
# Copied split/train/ground/001.jpeg to final/train/ground/001.jpeg
# Copied split/train/ground/040.jpeg to final/train/ground/040.jpeg
# Copied split/train/ground/041.jpeg to final/train/ground/041.jpeg
# Copied split/train/ground/020.jpeg to final/train/ground/020.jpeg
# Copied split/train/ground/061.jpeg to final/train/ground/061.jpeg
# Copied split/train/ground/007.jpeg to final/train/ground/007.jpeg
# Copied split/train/ground/011.jpeg to final/train/ground/011.jpeg
# Copied split/train/ground/066.jpeg to final/train/ground/066.jpeg
# Copied split/train/ground/027.jpeg to final/train/ground/027.jpeg
# Copied split/train/ground/026.jpeg to final/train/ground/026.jpeg
# Copied split/train/ground/030.jpeg to final/train/ground/030.jpeg
# Copied split/train/ground/047.jpeg to final/train/ground/047.jpeg
# Copied split/train/ground/010.jpeg to final/train/ground/010.jpeg
# Copied split/train/ground/006.jpeg to final/train/ground/006.jpeg
# Copied split/train/ground/029.jpeg to final/train/ground/029.jpeg
# Copied split/train/ground/044.jpeg to final/train/ground/044.jpeg
# Copied split/train/ground/013.jpeg to final/train/ground/013.jpeg
# Copied split/train/ground/005.jpeg to final/train/ground/005.jpeg
# Copied split/train/ground/025.jpeg to final/train/ground/025.jpeg
# Copied split/train/ground/064.jpeg to final/train/ground/064.jpeg
# Copied split/train/ground/009.jpeg to final/train/ground/009.jpeg
# Copied split/train/ground/008.jpeg to final/train/ground/008.jpeg
# Copied split/train/ground/049.jpeg to final/train/ground/049.jpeg
# Copied split/train/ground/032.jpeg to final/train/ground/032.jpeg
# Copied split/train/ground/065.jpeg to final/train/ground/065.jpeg
# Copied split/train/ground/004.jpeg to final/train/ground/004.jpeg
# Copied split/train/ground/012.jpeg to final/train/ground/012.jpeg
# Copied split/train/ground/045.jpeg to final/train/ground/045.jpeg
# Copied split/train/ground/023.jpeg to final/train/ground/023.jpeg
# Copied split/train/ground/062.jpeg to final/train/ground/062.jpeg
# Copied split/train/ground/035.jpeg to final/train/ground/035.jpeg
# Copied split/train/ground/019.jpeg to final/train/ground/019.jpeg
# Copied split/train/ground/058.jpeg to final/train/ground/058.jpeg
# Copied split/train/ground/039.jpeg to final/train/ground/039.jpeg
# Copied split/train/ground/042.jpeg to final/train/ground/042.jpeg
# Copied split/train/ground/015.jpeg to final/train/ground/015.jpeg
# Copied split/train/ground/054.jpeg to final/train/ground/054.jpeg
# Copied split/train/ground/055.jpeg to final/train/ground/055.jpeg
# Copied split/train/ground/002.jpeg to final/train/ground/002.jpeg
# Copied split/train/ground/014.jpeg to final/train/ground/014.jpeg
# Copied split/train/ground/043.jpeg to final/train/ground/043.jpeg
# Copied split/train/ground/038.jpeg to final/train/ground/038.jpeg
# Copied split/train/ground/059.jpeg to final/train/ground/059.jpeg
# Copied split/train/ground/063.jpeg to final/train/ground/063.jpeg
# Copied split/validation/raw/037.jpeg to final/validation/raw/037.jpeg
# Copied split/validation/raw/017.jpeg to final/validation/raw/017.jpeg
# Copied split/validation/raw/016.jpeg to final/validation/raw/016.jpeg
# Copied split/validation/raw/036.jpeg to final/validation/raw/036.jpeg
# Copied split/validation/raw/050.jpeg to final/validation/raw/050.jpeg
# Copied split/validation/raw/046.jpeg to final/validation/raw/046.jpeg
# Copied split/validation/raw/052.jpeg to final/validation/raw/052.jpeg
# Copied split/validation/raw/033.jpeg to final/validation/raw/033.jpeg
# Copied split/validation/raw/048.jpeg to final/validation/raw/048.jpeg
# Copied split/validation/raw/053.jpeg to final/validation/raw/053.jpeg
# Copied split/validation/ground/037.jpeg to final/validation/ground/037.jpeg
# Copied split/validation/ground/017.jpeg to final/validation/ground/017.jpeg
# Copied split/validation/ground/016.jpeg to final/validation/ground/016.jpeg
# Copied split/validation/ground/036.jpeg to final/validation/ground/036.jpeg
# Copied split/validation/ground/050.jpeg to final/validation/ground/050.jpeg
# Copied split/validation/ground/046.jpeg to final/validation/ground/046.jpeg
# Copied split/validation/ground/052.jpeg to final/validation/ground/052.jpeg
# Copied split/validation/ground/033.jpeg to final/validation/ground/033.jpeg
# Copied split/validation/ground/048.jpeg to final/validation/ground/048.jpeg
# Copied split/validation/ground/053.jpeg to final/validation/ground/053.jpeg
# Copied split/test/raw/056.jpeg to final/test/raw/056.jpeg
# Copied split/test/raw/057.jpeg to final/test/raw/057.jpeg
# Copied split/test/raw/031.jpeg to final/test/raw/031.jpeg
# Copied split/test/raw/051.jpeg to final/test/raw/051.jpeg
# Copied split/test/raw/024.jpeg to final/test/raw/024.jpeg
# Copied split/test/raw/028.jpeg to final/test/raw/028.jpeg
# Copied split/test/raw/003.jpeg to final/test/raw/003.jpeg
# Copied split/test/raw/018.jpeg to final/test/raw/018.jpeg
# Copied split/test/raw/034.jpeg to final/test/raw/034.jpeg
# Copied split/test/raw/022.jpeg to final/test/raw/022.jpeg
# Copied split/test/ground/056.jpeg to final/test/ground/056.jpeg
# Copied split/test/ground/057.jpeg to final/test/ground/057.jpeg
# Copied split/test/ground/031.jpeg to final/test/ground/031.jpeg
# Copied split/test/ground/051.jpeg to final/test/ground/051.jpeg
# Copied split/test/ground/024.jpeg to final/test/ground/024.jpeg
# Copied split/test/ground/028.jpeg to final/test/ground/028.jpeg
# Copied split/test/ground/003.jpeg to final/test/ground/003.jpeg
# Copied split/test/ground/018.jpeg to final/test/ground/018.jpeg
# Copied split/test/ground/034.jpeg to final/test/ground/034.jpeg
# Copied split/test/ground/022.jpeg to final/test/ground/022.jpeg
# Train raw files: ['060.jpeg', '021.jpeg', '001.jpeg', '040.jpeg', '041.jpeg', '020.jpeg', '061.jpeg', '007.jpeg', '011.jpeg', '066.jpeg', '027.jpeg', '026.jpeg', '030.jpeg', '047.jpeg', '010.jpeg', '006.jpeg', '029.jpeg', '044.jpeg', '013.jpeg', '005.jpeg', '025.jpeg', '064.jpeg', '009.jpeg', '008.jpeg', '049.jpeg', '032.jpeg', '065.jpeg', '004.jpeg', '012.jpeg', '045.jpeg', '023.jpeg', '062.jpeg', '035.jpeg', '019.jpeg', '058.jpeg', '039.jpeg', '042.jpeg', '015.jpeg', '054.jpeg', '055.jpeg', '002.jpeg', '014.jpeg', '043.jpeg', '038.jpeg', '059.jpeg', '063.jpeg']
# Train ground files: ['060.jpeg', '021.jpeg', '001.jpeg', '040.jpeg', '041.jpeg', '020.jpeg', '061.jpeg', '007.jpeg', '011.jpeg', '066.jpeg', '027.jpeg', '026.jpeg', '030.jpeg', '047.jpeg', '010.jpeg', '006.jpeg', '029.jpeg', '044.jpeg', '013.jpeg', '005.jpeg', '025.jpeg', '064.jpeg', '009.jpeg', '008.jpeg', '049.jpeg', '032.jpeg', '065.jpeg', '004.jpeg', '012.jpeg', '045.jpeg', '023.jpeg', '062.jpeg', '035.jpeg', '019.jpeg', '058.jpeg', '039.jpeg', '042.jpeg', '015.jpeg', '054.jpeg', '055.jpeg', '002.jpeg', '014.jpeg', '043.jpeg', '038.jpeg', '059.jpeg', '063.jpeg']
# Validation raw files: ['037.jpeg', '017.jpeg', '016.jpeg', '036.jpeg', '050.jpeg', '046.jpeg', '052.jpeg', '033.jpeg', '048.jpeg', '053.jpeg']
# Validation ground files: ['037.jpeg', '017.jpeg', '016.jpeg', '036.jpeg', '050.jpeg', '046.jpeg', '052.jpeg', '033.jpeg', '048.jpeg', '053.jpeg']
# Test raw files: ['056.jpeg', '057.jpeg', '031.jpeg', '051.jpeg', '024.jpeg', '028.jpeg', '003.jpeg', '018.jpeg', '034.jpeg', '022.jpeg']
# Test ground files: ['056.jpeg', '057.jpeg', '031.jpeg', '051.jpeg', '024.jpeg', '028.jpeg', '003.jpeg', '018.jpeg', '034.jpeg', '022.jpeg']
# Training dataset:
# Image batch shape: (32, 256, 256, 3)
# Mask batch shape: (32, 256, 256, 1)
# Validation dataset:
# Image batch shape: (10, 256, 256, 3)
# Mask batch shape: (10, 256, 256, 1)
# Test dataset:
# Image batch shape: (10, 256, 256, 3)
# Mask batch shape: (10, 256, 256, 1)

# %%
import os

def list_files(directory):
    return os.listdir(directory)

print("Train raw files:", list_files('final/train/raw'))
print("Train ground files:", list_files('final/train/ground'))
print("Validation raw files:", list_files('final/validation/raw'))
print("Validation ground files:", list_files('final/validation/ground'))
print("Test raw files:", list_files('final/test/raw'))
print("Test ground files:", list_files('final/test/ground'))
# Out:
# Train raw files: []
# Train ground files: []
# Validation raw files: []
# Validation ground files: []
# Test raw files: []
# Test ground files: []
