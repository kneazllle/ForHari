# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16941, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 16941 (delta 70), reused 92 (delta 48), pack-reused 16805 (from 1)
# Receiving objects: 100% (16941/16941), 15.70 MiB | 503.00 KiB/s, done.
# Resolving deltas: 100% (11603/11603), done.
# /Users/anandhu/Documents/miniProject/yolov5
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...

# %%
import torch
import pandas as pd
from matplotlib import pyplot as plt
from PIL import Image

# Load YOLOv5 model (pretrained on COCO dataset)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Load an image
img = '/Users/anandhu/Documents/miniProject/002.jpeg'  # Replace with your image path

# Perform inference
results = model(img)

# Display results
results.show()

# Extract results
df = results.pandas().xyxy[0]  # Pandas DataFrame of results

# Display the coordinates of each detected object
for index, row in df.iterrows():
    x_start = int(row['xmin'])
    y_start = int(row['ymin'])
    x_length = int(row['xmax'] - row['xmin'])
    y_length = int(row['ymax'] - row['ymin'])
    
    print(f"Object {index + 1}:")
    print(f"  - Class: {row['name']}")
    print(f"  - Confidence: {row['confidence']:.2f}")
    print(f"  - x_start: {x_start}")
    print(f"  - y_start: {y_start}")
    print(f"  - x_length: {x_length}")
    print(f"  - y_length: {y_length}")
    print()
# Out:
# Using cache found in /Users/anandhu/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-9-2 Python-3.12.4 torch-2.4.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /Users/anandhu/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=280x205>
# Object 1:
#   - Class: frisbee
#   - Confidence: 0.29
#   - x_start: 131
#   - y_start: 75
#   - x_length: 61
#   - y_length: 51
